# %% [markdown]
# #### Encoding and Decoding using Spark

# %%
# %sql
-- Let us try to encode the word "Azure" and print it in hex format
SELECT hex(encode('Azure', 'UTF-16'));
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>hex(encode(Azure, UTF-16))</th></tr></thead><tbody><tr><td>FEFF0041007A007500720065</td></tr></tbody></table></div>

# %%
# %sql
-- Now let us try to decode the hex value
SELECT decode(X'FEFF0041007A007500720065', 'UTF-16')
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>decode(X'FEFF0041007A007500720065', UTF-16)</th></tr></thead><tbody><tr><td>Azure</td></tr></tbody></table></div>
